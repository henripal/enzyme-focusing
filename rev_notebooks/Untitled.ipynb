# %%
a <- c(1, 2, 4, 5)

# %%
b <- c(1, 3, 5 , 7)

# %%
ccf(a,b)
# Out:
# Plot with title “a & b”

# %%
xcf(a,b)
# Out:
# Error in eval(expr, envir, enclos): could not find function "xcf"
# Traceback:

# %%
acf(a,b)
# Out:
# Plot with title “Series  a”

# %%
res <- ccf(a,b)
# Out:
# Plot with title “a & b”

# %%
names(res)
# Out:
# [1] "acf"    "type"   "n.used" "lag"    "series" "snames"

# %%
res
# Out:
# Autocorrelations of series ‘X’, by lag
#
#     -3     -2     -1      0      1      2      3
# -0.424 -0.354  0.283  0.990  0.283 -0.354 -0.424

# %%
res$n.used
# Out:
# [1] 4

# %%
1/sqrt(4)
# Out:
# [1] 0.5

# %%
print(res)
# Out:
# Autocorrelations of series ‘X’, by lag
#
#     -3     -2     -1      0      1      2      3
# -0.424 -0.354  0.283  0.990  0.283 -0.354 -0.424

# %%
summary(res)
# Out:
#        Length Class  Mode
# acf    7      -none- numeric
# type   1      -none- character
# n.used 1      -none- numeric
# lag    7      -none- numeric
# series 1      -none- character
# snames 1      -none- character

# %%
install.packages("MTS")
# Out:
# also installing the dependencies ‘gss’, ‘stabledist’, ‘timeDate’, ‘timeSeries’, ‘fBasics’, ‘fGarch’, ‘mvtnorm’
#
# Warning message in install.packages("MTS"):
# “installation of package ‘MTS’ had non-zero exit status”Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library()
